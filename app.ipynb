# %%
# !python -m pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (1.56.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (7.0.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.3.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.47)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.4.4)
# Requirement already satisfied: packaging>=20 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.0.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.20.0)
# Requirement already satisfied: colorama in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\jusan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app.py
import streamlit as st
import time
from datetime import datetime, timedelta

st.set_page_config(
 page_title="Log Diagnosis Remediation Dashboard",
 layout="wide"
)

# -----------------------------
# Sample Data
# -----------------------------
records = [
 {
 "S.No": 1,
 "Timestamp": (datetime.now() - timedelta(minutes=12)).strftime("%Y-%m-%d %H:%M:%S"),
 "Issue": "High application response latency detected",
 "Root Cause": "Thread pool saturation observed in application server logs",
 "Resolution": "Increase application worker thread pool size",
 "Remediation Steps": "Update server thread pool config and restart application service"
 },
 {
 "S.No": 2,
 "Timestamp": (datetime.now() - timedelta(minutes=25)).strftime("%Y-%m-%d %H:%M:%S"),
 "Issue": "Database connection timeout errors",
 "Root Cause": "Connection pool exhausted due to long-running SQL queries",
 "Resolution": "Optimize slow queries and increase DB connection pool limit",
 "Remediation Steps": "Kill stale DB sessions, tune SQL indexes, and update pool settings"
 },
 {
 "S.No": 3,
 "Timestamp": (datetime.now() - timedelta(minutes=41)).strftime("%Y-%m-%d %H:%M:%S"),
 "Issue": "Frequent application server restarts",
 "Root Cause": "OutOfMemoryError found in application server logs",
 "Resolution": "Increase JVM heap memory and analyze memory leaks",
 "Remediation Steps": "Update JVM Xmx value, enable heap dump, and restart application"
 },
 {
 "S.No": 4,
 "Timestamp": (datetime.now() - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M:%S"),
 "Issue": "CPU utilization above threshold",
 "Root Cause": "Infrastructure metrics show sustained CPU usage above 90%",
 "Resolution": "Scale application instances horizontally",
 "Remediation Steps": "Add additional application server node and rebalance traffic"
 },
 {
 "S.No": 5,
 "Timestamp": (datetime.now() - timedelta(hours=2)).strftime("%Y-%m-%d %H:%M:%S"),
 "Issue": "Disk space warning on database server",
 "Root Cause": "Database logs and infra metrics indicate rapid archive log growth",
 "Resolution": "Clean old archive logs and increase disk capacity",
 "Remediation Steps": "Backup archive logs, purge expired logs, and expand storage volume"
 }
]

# -----------------------------
# Custom CSS
# -----------------------------
st.markdown(
 """
 <style>
 .main-title {
 font-size: 32px;
 font-weight: 700;
 color: #1f2937;
 margin-bottom: 5px;
 }

 .subtitle {
 font-size: 16px;
 color: #6b7280;
 margin-bottom: 25px;
 }

 .table-header {
 background: linear-gradient(90deg, #1f2937, #374151);
 color: white;
 font-weight: 700;
 padding: 14px 10px;
 border-radius: 10px;
 text-align: center;
 font-size: 14px;
 }

 .table-cell {
 background-color: #ffffff;
 padding: 14px 10px;
 border-radius: 10px;
 min-height: 95px;
 box-shadow: 0 2px 8px rgba(0,0,0,0.08);
 font-size: 14px;
 color: #111827;
 display: flex;
 align-items: center;
 }

 .sno-cell {
 justify-content: center;
 font-weight: 700;
 color: #2563eb;
 }

 div.stButton > button {
 background-color: #16a34a;
 color: white;
 border: none;
 border-radius: 6px;
 padding: 10px 18px;
 font-weight: 700;
 width: 100%;
 height: 48px;
 }

 div.stButton > button:hover {
 background-color: #15803d;
 color: white;
 border: none;
 }

 div.stButton > button:active {
 background-color: #166534;
 color: white;
 }

 .toast-message {
 position: fixed;
 top: 70px;
 right: 30px;
 z-index: 9999;
 padding: 16px 22px;
 border-radius: 10px;
 color: white;
 font-weight: 700;
 box-shadow: 0 8px 20px rgba(0,0,0,0.25);
 animation: slideIn 0.3s ease-out;
 }

 .toast-loading {
 background-color: #2563eb;
 }

 .toast-success {
 background-color: #16a34a;
 }

 @keyframes slideIn {
 from {
 opacity: 0;
 transform: translateX(30px);
 }
 to {
 opacity: 1;
 transform: translateX(0);
 }
 }
 </style>
 """,
 unsafe_allow_html=True
)

# -----------------------------
# Page Header
# -----------------------------
st.markdown('<div class="main-title">Log Diagnosis Remediation Dashboard</div>', unsafe_allow_html=True)
st.markdown(
 '<div class="subtitle">Issues diagnosed from application server logs, database logs, and infrastructure metrics logs</div>',
 unsafe_allow_html=True
)

toast_placeholder = st.empty()

# -----------------------------
# Function to show remediation status
# -----------------------------
def show_remediation_status():
 toast_placeholder.markdown(
 """
 <div class="toast-message toast-loading">
 Implementing Remediation
 </div>
 """,
 unsafe_allow_html=True
 )

 time.sleep(5)

 toast_placeholder.markdown(
 """
 <div class="toast-message toast-success">
 Remediation Implemented
 </div>
 """,
 unsafe_allow_html=True
 )

 time.sleep(3)
 toast_placeholder.empty()

# -----------------------------
# Table Header
# -----------------------------
header_cols = st.columns([0.6, 1.4, 2.0, 2.2, 2.0, 2.6, 1.6])

headers = [
 "S.No",
 "Timestamp",
 "Issue",
 "Root Cause",
 "Resolution",
 "Remediation Steps",
 "Button"
]

for col, header in zip(header_cols, headers):
 col.markdown(f'<div class="table-header">{header}</div>', unsafe_allow_html=True)

st.markdown("<br>", unsafe_allow_html=True)

# -----------------------------
# Table Rows
# -----------------------------
for record in records:
 row_cols = st.columns([0.6, 1.4, 2.0, 2.2, 2.0, 2.6, 1.6])

 row_cols[0].markdown(
 f'<div class="table-cell sno-cell">{record["S.No"]}</div>',
 unsafe_allow_html=True
 )

 row_cols[1].markdown(
 f'<div class="table-cell">{record["Timestamp"]}</div>',
 unsafe_allow_html=True
 )

 row_cols[2].markdown(
 f'<div class="table-cell">{record["Issue"]}</div>',
 unsafe_allow_html=True
 )

 row_cols[3].markdown(
 f'<div class="table-cell">{record["Root Cause"]}</div>',
 unsafe_allow_html=True
 )

 row_cols[4].markdown(
 f'<div class="table-cell">{record["Resolution"]}</div>',
 unsafe_allow_html=True
 )

 row_cols[5].markdown(
 f'<div class="table-cell">{record["Remediation Steps"]}</div>',
 unsafe_allow_html=True
 )

 with row_cols[6]:
    st.write("")
    if st.button( "Implement Remediation", key=f"remediate_{record['S.No']}" ):
        show_remediation_status()

 st.markdown("<br>", unsafe_allow_html=True)
# Out:
# 2026-06-16 16:48:02.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-16 16:48:02.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run app.py
